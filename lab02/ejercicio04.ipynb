-- %%
--Función que aplica una transformación a una lista

-- %%
-- Definición de la función de conversión
celsiusAFahrenheit :: Double -> Double
celsiusAFahrenheit c = c * 9/5 + 32

-- Función que procesa lecturas
procesarLecturas :: (Double -> Double) -> [Double] -> [Double]
procesarLecturas = map
--procesarLecturas celsiusAFahrenheit [0,12,20]
-- Out:
-- [32.0,53.6,68.0]

-- %%
-- Retorna una función que filtra usando el predicado dado
crearFiltro :: (a -> Bool) -> ([a] -> [a])
crearFiltro predicado = filter predicado
-- O simplemente:
-- crearFiltro = filter

-- Ejemplo:
-- soloPares = crearFiltro even
soloPares [1..10] == [2,4,6,8,10]
-- Out:
-- Line 3: Eta reduce
-- Found:
-- crearFiltro predicado = filter predicado
-- Why not:
-- crearFiltro = filter
-- <interactive>:1:1: error: [GHC-88464] Variable not in scope: soloPares :: [a0] -> [a1]
