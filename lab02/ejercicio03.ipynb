-- %%
sumaLista :: [Int] -> Int
sumaLista = foldr (+) 0
--sumaLista [2,3,4]
-- Out:
-- Line 2: Use sum
-- Found:
-- foldr (+) 0
-- Why not:
-- sum
-- 9

-- %%
mayoresQue10 :: [Int] -> Int
mayoresQue10 = length . filter (>10)
--mayoresQue10 [15,3,6,38]
-- Out:
-- 2

-- %%
productoLista :: [Int] -> Int
productoLista = foldr (*) 1
--productoLista [4,5]
-- Out:
-- Line 2: Use product
-- Found:
-- foldr (*) 1
-- Why not:
-- product
-- 20

-- %%
celsiusAFahrenheit :: [Double] -> [Double]
celsiusAFahrenheit = map (\c -> c * 9/5 + 32)
--celsiusAFahrenheit [23,0,56,78]
-- Out:
-- [73.4,32.0,132.8,172.4]

-- %%
ajustarImpares :: [Int] -> [Int]
ajustarImpares = map (\x -> if odd x then x + 5 else x)
--ajustarImpares [7,9,4]
-- Out:
-- [12,14,4]

-- %%
--usando filter

-- %%
nombresLargos :: [String] -> [String]
nombresLargos = filter (\nombre -> length nombre > 5)

-- %%
soloNegativos :: [Int] -> [Int]
soloNegativos = filter (<0)

-- %%
edadesUniversitarios :: [Int] -> [Int]
edadesUniversitarios = filter (\edad -> edad >= 18 && edad <= 25)
edadesUniversitarios [45,23,23]
-- Out:
-- [23,23]

-- %%
--Funciones con filter y map

-- %%
agregarIVA :: [Double] -> [Double]
agregarIVA = map (\precio -> if precio >= 1000 then precio * 1.19 else precio)
--agregarIVA [3500,500000]
-- Out:
-- [4165.0,595000.0]

-- %%
longitudesVocales :: [String] -> [Int]
longitudesVocales = map length . filter (\palabra -> not (null palabra) && 
    (head palabra) `elem` "aeiouAEIOU")
-- Out:
-- Line 3: Redundant bracket
-- Found:
-- (head palabra) `elem` "aeiouAEIOU"
-- Why not:
-- head palabra `elem` "aeiouAEIOU"

-- %%
cuadradosPares :: [Int] -> [Int]
cuadradosPares = map (^2) . filter even
--cuadradosPares [6,9,47]
-- Out:
-- [36]

-- %%
--Funciones con any o all

-- %%
hayNegativo :: [Int] -> Bool
hayNegativo = any (<0)

-- %%
todosPares :: [Int] -> Bool
todosPares = all even

-- %%
import Data.Char (isUpper)

nombresCorrectos :: [String] -> Bool
nombresCorrectos = all (\nombre -> not (null nombre) && isUpper (head nombre))
--nombresCorrectos ["Saul"]
-- Out:
-- True

-- %%
--Funciones con takeWhile o dropWhile

-- %%
menoresQue100 :: [Int] -> [Int]
menoresQue100 = takeWhile (<100)

-- %%
sinCerosIniciales :: [Int] -> [Int]
sinCerosIniciales = dropWhile (==0)
--sinCerosIniciales [0,5,6]
